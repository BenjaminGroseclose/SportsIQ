# %%
import pandas as pd
import pymongo as mongo

mlbPlayers = pd.read_csv('./mlb-players.csv')

print(mlbPlayers.shape)
# Out:
# (1472, 35)

# %%
# Connect to MongoDB
client = mongo.MongoClient('mongodb+srv://application:4kHYKePdUibzBTq3@sportsiq.hulfg.mongodb.net/')
db = client['sport-data']
collection = db['mlb-hitters']

# %%
mlbPlayers = mlbPlayers.drop(mlbPlayers[mlbPlayers['Rk'] == 'Rk'].index)

print(mlbPlayers.shape)
# Out:
# (1472, 35)

# %%
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('*', '')
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('#', '')

# %%
mlbPlayerScrubbed = pd.DataFrame({
	'player': mlbPlayers['Player'],
	'age': mlbPlayers['Age'],
	'team': mlbPlayers['Team'],
	'league': mlbPlayers['Lg'],
	'war': mlbPlayers['WAR'],
	'games': mlbPlayers['G'],
	'plateAppearances': mlbPlayers['PA'],
	'atBats': mlbPlayers['AB'],
	'runs': mlbPlayers['R'],
	'hits': mlbPlayers['H'],
	'doubles': mlbPlayers['2B'],
	'triples': mlbPlayers['3B'],
	'homeRuns': mlbPlayers['HR'],
	'rbi': mlbPlayers['RBI'],
	'stolenBases': mlbPlayers['SB'],
	'caught': mlbPlayers['CS'],
	'baseOnBalls': mlbPlayers['BB'],
	'strikeouts': mlbPlayers['SO'],
	'battingAverage': mlbPlayers['BA'],
	'onBasePercentage': mlbPlayers['OBP'],
	'slug': mlbPlayers['SLG'],
	'opsPlus': mlbPlayers['OPS+'],
	'rOBA': mlbPlayers['rOBA'],
	'year': 2015
})

print(mlbPlayerScrubbed.head())
print(mlbPlayerScrubbed.shape)
# Out:
#              player  age team league  war  games  plateAppearances  atBats  \
# 0     Manny Machado   22  BAL     AL  7.5    162               713     633
# 1    Josh Donaldson   29  TOR     AL  7.1    158               711     620
# 2      Brian Dozier   28  MIN     AL  2.8    157               704     628
# 3     Anthony Rizzo   25  CHC     NL  6.4    160               701     586
# 4  Paul Goldschmidt   27  ARI     NL  8.3    159               695     567
#
#    runs  hits  ...  stolenBases  caught  baseOnBalls  strikeouts  \
# 0   102   181  ...           20       8           70         111
# 1   122   184  ...            6       0           73         133
# 2   101   148  ...           12       4           61         148
# 3    94   163  ...           17       6           78         105
# 4   103   182  ...           21       5          118         151
#
#    battingAverage  onBasePercentage   slug  opsPlus   rOBA  year
# 0           0.286             0.359  0.502    132.0  0.375  2015
# 1           0.297             0.371  0.568    151.0  0.403  2015
# 2           0.236             0.307  0.444    104.0  0.326  2015
# 3           0.278             0.387  0.512    146.0  0.397  2015
# 4           0.321             0.435  0.570    168.0  0.432  2015
#
# [5 rows x 24 columns]
# (1472, 24)

# %%
# Convert DataFrame to a list of dictionaries
data = mlbPlayerScrubbed.to_dict('records')

# Insert the data into MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67b0156d823d13be50111a52'), ObjectId('67b0156d823d13be50111a53'), ObjectId('67b0156d823d13be50111a54'), ObjectId('67b0156d823d13be50111a55'), ObjectId('67b0156d823d13be50111a56'), ObjectId('67b0156d823d13be50111a57'), ObjectId('67b0156d823d13be50111a58'), ObjectId('67b0156d823d13be50111a59'), ObjectId('67b0156d823d13be50111a5a'), ObjectId('67b0156d823d13be50111a5b'), ObjectId('67b0156d823d13be50111a5c'), ObjectId('67b0156d823d13be50111a5d'), ObjectId('67b0156d823d13be50111a5e'), ObjectId('67b0156d823d13be50111a5f'), ObjectId('67b0156d823d13be50111a60'), ObjectId('67b0156d823d13be50111a61'), ObjectId('67b0156d823d13be50111a62'), ObjectId('67b0156d823d13be50111a63'), ObjectId('67b0156d823d13be50111a