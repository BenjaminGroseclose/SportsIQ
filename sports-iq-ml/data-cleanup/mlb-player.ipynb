# %%
import pandas as pd
import pymongo as mongo

mlbPlayers = pd.read_csv('./mlb-players.csv')

print(mlbPlayers.shape)
# Out:
# (895, 35)

# %%
# Connect to MongoDB
client = mongo.MongoClient('mongodb+srv://application:4kHYKePdUibzBTq3@sportsiq.hulfg.mongodb.net/')
db = client['sport-data']
collection = db['mlb-hitters']

# %%
mlbPlayers = mlbPlayers.drop(mlbPlayers[mlbPlayers['Rk'] == 'Rk'].index)

print(mlbPlayers.shape)
# Out:
# (895, 35)

# %%
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('*', '')
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('#', '')

# %%
mlbPlayerScrubbed = pd.DataFrame({
	'player': mlbPlayers['Player'],
	'age': mlbPlayers['Age'],
	'team': mlbPlayers['Team'],
	'league': mlbPlayers['Lg'],
	'war': mlbPlayers['WAR'],
	'games': mlbPlayers['G'],
	'plateAppearances': mlbPlayers['PA'],
	'atBats': mlbPlayers['AB'],
	'runs': mlbPlayers['R'],
	'hits': mlbPlayers['H'],
	'doubles': mlbPlayers['2B'],
	'triples': mlbPlayers['3B'],
	'homeRuns': mlbPlayers['HR'],
	'rbi': mlbPlayers['RBI'],
	'stolenBases': mlbPlayers['SB'],
	'caught': mlbPlayers['CS'],
	'baseOnBalls': mlbPlayers['BB'],
	'strikeouts': mlbPlayers['SO'],
	'battingAverage': mlbPlayers['BA'],
	'onBasePercentage': mlbPlayers['OBP'],
	'slug': mlbPlayers['SLG'],
	'opsPlus': mlbPlayers['OPS+'],
	'rOBA': mlbPlayers['rOBA'],
	'year': 2024
})

print(mlbPlayerScrubbed.head())
print(mlbPlayerScrubbed.shape)
# Out:
#              player  age team league  war  games  plateAppearances  atBats  \
# 0      Jarren Duran   27  BOS     AL  8.7    160               735     671
# 1     Shohei Ohtani   29  LAD     NL  9.2    159               731     636
# 2  Gunnar Henderson   23  BAL     AL  9.1    159               719     630
# 3     Marcus Semien   33  TEX     AL  4.1    159               718     650
# 4         Juan Soto   25  NYY     AL  7.9    157               713     576
#
#    runs  hits  ...  stolenBases  caught  baseOnBalls  strikeouts  \
# 0   111   191  ...           34       7           54         160
# 1   134   197  ...           59       4           81         162
# 2   118   177  ...           21       4           78         159
# 3   101   154  ...            8       3           64         105
# 4   128   166  ...            7       4          129         119
#
#    battingAverage  onBasePercentage   slug  opsPlus   rOBA  year
# 0           0.285             0.342  0.492    129.0  0.373  2024
# 1           0.310             0.390  0.646    190.0  0.449  2024
# 2           0.281             0.364  0.529    159.0  0.385  2024
# 3           0.237             0.308  0.391    100.0  0.310  2024
# 4           0.288             0.419  0.569    178.0  0.424  2024
#
# [5 rows x 24 columns]
# (895, 24)

# %%
# Convert DataFrame to a list of dictionaries
data = mlbPlayerScrubbed.to_dict('records')

# Insert the data into MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67aacc9f9830651790a4d700'), ObjectId('67aacc9f9830651790a4d701'), ObjectId('67aacc9f9830651790a4d702'), ObjectId('67aacc9f9830651790a4d703'), ObjectId('67aacc9f9830651790a4d704'), ObjectId('67aacc9f9830651790a4d705'), ObjectId('67aacc9f9830651790a4d706'), ObjectId('67aacc9f9830651790a4d707'), ObjectId('67aacc9f9830651790a4d708'), ObjectId('67aacc9f9830651790a4d709'), ObjectId('67aacc9f9830651790a4d70a'), ObjectId('67aacc9f9830651790a4d70b'), ObjectId('67aacc9f9830651790a4d70c'), ObjectId('67aacc9f9830651790a4d70d'), ObjectId('67aacc9f9830651790a4d70e'), ObjectId('67aacc9f9830651790a4d70f'), ObjectId('67aacc9f9830651790a4d710'), ObjectId('67aacc9f9830651790a4d711'), ObjectId('67aacc9f9830651790a4d712'), ObjectId('67aacc9f9830651790a4d713'), Obj