# %%
import pandas as pd
import pymongo as mongo

mlbPlayers = pd.read_csv('./mlb-players.csv')

print(mlbPlayers.shape)
# Out:
# (892, 35)

# %%
# Connect to MongoDB
client = mongo.MongoClient('mongodb+srv://application:4kHYKePdUibzBTq3@sportsiq.hulfg.mongodb.net/')
db = client['sport-data']
collection = db['mlb-hitters']

# %%
mlbPlayers = mlbPlayers.drop(mlbPlayers[mlbPlayers['Rk'] == 'Rk'].index)

print(mlbPlayers.shape)
# Out:
# (892, 35)

# %%
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('*', '')
mlbPlayers['Player'] = mlbPlayers['Player'].str.replace('#', '')

# %%
mlbPlayerScrubbed = pd.DataFrame({
	'player': mlbPlayers['Player'],
	'age': mlbPlayers['Age'],
	'team': mlbPlayers['Team'],
	'league': mlbPlayers['Lg'],
	'war': mlbPlayers['WAR'],
	'games': mlbPlayers['G'],
	'plateAppearances': mlbPlayers['PA'],
	'atBats': mlbPlayers['AB'],
	'runs': mlbPlayers['R'],
	'hits': mlbPlayers['H'],
	'doubles': mlbPlayers['2B'],
	'triples': mlbPlayers['3B'],
	'homeRuns': mlbPlayers['HR'],
	'rbi': mlbPlayers['RBI'],
	'stolenBases': mlbPlayers['SB'],
	'caught': mlbPlayers['CS'],
	'baseOnBalls': mlbPlayers['BB'],
	'strikeouts': mlbPlayers['SO'],
	'battingAverage': mlbPlayers['BA'],
	'onBasePercentage': mlbPlayers['OBP'],
	'slug': mlbPlayers['SLG'],
	'opsPlus': mlbPlayers['OPS+'],
	'rOBA': mlbPlayers['rOBA'],
	'year': 1991
})

print(mlbPlayerScrubbed.head())
print(mlbPlayerScrubbed.shape)
# Out:
#             player  age team league  war  games  plateAppearances  atBats  \
# 0     Paul Molitor   34  MIL     AL  5.3    158               752     665
# 1     Brett Butler   34  LAD     NL  5.1    161               730     615
# 2  Harold Reynolds   30  SEA     AL  2.7    161               728     631
# 3     Rubén Sierra   25  TEX     AL  5.1    161               726     661
# 4   Roberto Alomar   23  TOR     AL  4.6    161               719     637
#
#    runs  hits  ...  stolenBases  caught  baseOnBalls  strikeouts  \
# 0   133   216  ...           19       8           77          62
# 1   112   182  ...           38      28          108          79
# 2    95   160  ...           28       8           72          63
# 3   110   203  ...           16       4           56          91
# 4    88   188  ...           53      11           57          86
#
#    battingAverage  onBasePercentage   slug  opsPlus   rOBA  year
# 0           0.325             0.399  0.489    147.0  0.398  1991
# 1           0.296             0.401  0.343    114.0  0.354  1991
# 2           0.254             0.332  0.341     87.0  0.330  1991
# 3           0.307             0.357  0.502    138.0  0.387  1991
# 4           0.295             0.354  0.436    115.0  0.376  1991
#
# [5 rows x 24 columns]
# (892, 24)

# %%
# Convert DataFrame to a list of dictionaries
data = mlbPlayerScrubbed.to_dict('records')

# Insert the data into MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67b17369229c3aa415e10c65'), ObjectId('67b17369229c3aa415e10c66'), ObjectId('67b17369229c3aa415e10c67'), ObjectId('67b17369229c3aa415e10c68'), ObjectId('67b17369229c3aa415e10c69'), ObjectId('67b17369229c3aa415e10c6a'), ObjectId('67b17369229c3aa415e10c6b'), ObjectId('67b17369229c3aa415e10c6c'), ObjectId('67b17369229c3aa415e10c6d'), ObjectId('67b17369229c3aa415e10c6e'), ObjectId('67b17369229c3aa415e10c6f'), ObjectId('67b17369229c3aa415e10c70'), ObjectId('67b17369229c3aa415e10c71'), ObjectId('67b17369229c3aa415e10c72'), ObjectId('67b17369229c3aa415e10c73'), ObjectId('67b17369229c3aa415e10c74'), ObjectId('67b17369229c3aa415e10c75'), ObjectId('67b17369229c3aa415e10c76'), ObjectId('67b17369229c3aa415e10c77'), ObjectId('67b17369229c3aa415e10c78'), ObjectId('67b17369229c3aa415