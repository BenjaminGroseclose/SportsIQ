# %%
import nflreadpy as nfl

contracts = nfl.load_contracts().to_pandas()

print(contracts.columns)
# Out:
# Index(['player', 'position', 'team', 'is_active', 'year_signed', 'years',
#        'value', 'apy', 'guaranteed', 'apy_cap_pct', 'inflated_value',
#        'inflated_apy', 'inflated_guaranteed', 'player_page', 'otc_id',
#        'gsis_id', 'date_of_birth', 'height', 'weight', 'college', 'draft_year',
#        'draft_round', 'draft_overall', 'draft_team', 'cols'],
#       dtype='object')

# %%
contracts.head()
# Out:
#            player position     team  is_active  year_signed  years    value  \
# 0      Joe Burrow       QB  Bengals       True         2023    5.0  275.000
# 1   Aaron Rodgers       QB   GB/NYJ      False         2022    5.0  150.815
# 2      Josh Allen       QB    Bills      False         2021    6.0  258.000
# 3  Russell Wilson       QB  Broncos      False         2022    5.0  245.000
# 4    Dak Prescott       QB  Cowboys       True         2024    4.0  240.000
#
#          apy  guaranteed  apy_cap_pct  ...     gsis_id  date_of_birth  height  \
# 0  55.000000     146.510        0.245  ...  00-0036442           None    6'4"
# 1  50.271667     101.415        0.241  ...  00-0023459           None    6'2"
# 2  43.000000     100.000        0.236  ...  00-0034857           None    6'5"
# 3  49.000000     124.000        0.235  ...  00-0029263           None   5'11"
# 4  60.000000     129.000        0.235  ...  00-0033077           None    6'2"
#
# ...
