# %%
import nflreadpy as nfl

df = nfl.load_contracts()

df.columns
# Out:
# ['player',
#  'position',
#  'team',
#  'is_active',
#  'year_signed',
#  'years',
#  'value',
#  'apy',
#  'guaranteed',
#  'apy_cap_pct',
#  'inflated_value',
#  'inflated_apy',
#  'inflated_guaranteed',
#  'player_page',
#  'otc_id',
#  'gsis_id',
#  'date_of_birth',
#  'height',
#  'weight',
#  'college',
#  'draft_year',
#  'draft_round',
#  'draft_overall',
#  'draft_team',
#  'cols']
