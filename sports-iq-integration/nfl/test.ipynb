# %%
import nflreadpy as nfl
import pandas as pd

contracts = nfl.load_contracts().to_pandas()

print(contracts.columns)
# Out:
# Index(['player', 'position', 'team', 'is_active', 'year_signed', 'years',
#        'value', 'apy', 'guaranteed', 'apy_cap_pct', 'inflated_value',
#        'inflated_apy', 'inflated_guaranteed', 'player_page', 'otc_id',
#        'gsis_id', 'date_of_birth', 'height', 'weight', 'college', 'draft_year',
#        'draft_round', 'draft_overall', 'draft_team', 'cols'],
#       dtype='object')

# %%
# Only show columsn player, year_signed, and cols

test = contracts[['player', 'year_signed', 'cols']]
print(test.head())

contracts.to_csv('contracts.csv', index=False)
# Out:
#            player  year_signed  \
# 0      Joe Burrow         2023
# 1   Aaron Rodgers         2022
# 2      Josh Allen         2021
# 3  Russell Wilson         2022
# 4    Dak Prescott         2024
#
#                                                 cols
# 0  [{'year': '2020', 'team': 'Bengals', 'base_sal...
# 1  [{'year': '2005', 'team': 'Packers', 'base_sal...
# 2  [{'year': '2018', 'team': 'Bills', 'base_salar...
# 3  [{'year': '2012', 'team': 'Seahawks', 'base_sa...
# 4  [{'year': '2016', 'team': 'Cowboys', 'base_sal...

# %%
# Where name is Aaron Rodgers
rodgers_contracts = contracts[contracts['player'] == 'Philip Rivers']
rodgers_contracts.head()

rodgers_contracts.to_csv('rodgers_contracts.csv', index=False)
