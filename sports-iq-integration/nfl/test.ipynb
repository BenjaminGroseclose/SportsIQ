# %%
import nflreadpy as nfl

def_adv = nfl.load_pfr_advstats(seasons=[2025], stat_type="def", summary_level="season").to_pandas()

print(def_adv.columns)
# Out:
# Index(['season', 'player', 'pfr_id', 'tm', 'age', 'pos', 'g', 'gs', 'int',
#        'tgt', 'cmp', 'cmp_percent', 'yds', 'yds_cmp', 'yds_tgt', 'td', 'rat',
#        'dadot', 'air', 'yac', 'bltz', 'hrry', 'qbkd', 'sk', 'prss', 'comb',
#        'm_tkl', 'm_tkl_percent', 'loaded', 'bats'],
#       dtype='object')
