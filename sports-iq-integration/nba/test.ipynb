# %%
import nba_api.stats.endpoints as nba
from nba_api.stats.static import teams


players = nba.commonteamroster.CommonTeamRoster(team_id=1610612739)  # Example team ID for the Los Angeles Lakers

# print(players.columns)

# %%
df = nba.commonallplayers.CommonAllPlayers(is_only_current_season=1).get_data_frames()[0]

df
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0      1630173        Achiuwa, Precious   Precious Achiuwa             1
# 1       203500            Adams, Steven       Steven Adams             1
# 2      1628389             Adebayo, Bam        Bam Adebayo             1
# 3      1630534            Agbaji, Ochai       Ochai Agbaji             1
# 4      1630583            Aldama, Santi       Santi Aldama             1
# ..         ...                      ...                ...           ...
# 536    1642911          Zikarsky, Rocco     Rocco Zikarsky             1
# 537    1627826             Zubac, Ivica        Ivica Zubac             1
# 538    1641783        da Silva, Tristan   Tristan da Silva             1
# 539    1642365          Đurišić, Nikola     Nikola Đurišić             1
# 540     203967             Šarić, Dario        Dario Šarić             1
#
#     FROM_YEAR TO_YEAR        PLAYERCODE       PLAYER_SLUG     TEAM_ID  \
# ...

# %%
df = nba.commonteamroster.CommonTeamRoster(team_id=1610612737).get_data_frames()[0]

df
# Out:
#         TeamID SEASON LeagueID                    PLAYER   NICKNAME  \
# 0   1610612737   2025       00             Jalen Johnson      Jalen
# 1   1610612737   2025       00            Keaton Wallace     Keaton
# 2   1610612737   2025       00               CJ McCollum         CJ
# 3   1610612737   2025       00              Luke Kennard       Luke
# 4   1610612737   2025       00             Dyson Daniels      Dyson
# 5   1610612737   2025       00  Nickeil Alexander-Walker    Nickeil
# 6   1610612737   2025       00        Kristaps Porziņģis   Kristaps
# 7   1610612737   2025       00        Zaccharie Risacher  Zaccharie
# 8   1610612737   2025       00               RayJ Dennis       RayJ
# 9   1610612737   2025       00              N'Faly Dante     N'Faly
# 10  1610612737   2025       00                Asa Newell        Asa
# 11  1610612737   2025       00            Onyeka Okongwu     Onyeka
# 12  1610612737   2025       00            Mouhamed Gueye   Mouhamed
# ...

# %%
nba_teams = teams.get_teams()

print(nba_teams)
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Georgia', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}, {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}, {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}, {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}, {'id': 1610612742, 'full_name': 'Dallas Mavericks', 'abbreviation': 'DAL', 'nickname': 'Mavericks', 'city': 'Dallas', 'state': 'Texas', 'year_founded': 1980}, {'id': 1610612743, 'full_name
# ...

# %%
players.head()
# Out:
#    PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME       PLAYER_SLUG     TEAM_ID  \
# 0    1630173          Achiuwa          Precious  precious-achiuwa  1610612758
# 1     203500            Adams            Steven      steven-adams  1610612745
# 2    1628389          Adebayo               Bam       bam-adebayo  1610612748
# 3    1630534           Agbaji             Ochai      ochai-agbaji  1610612761
# 4    1630583           Aldama             Santi      santi-aldama  1610612763
#
#    TEAM_SLUG  IS_DEFUNCT   TEAM_CITY  TEAM_NAME TEAM_ABBREVIATION  ...  \
# 0      kings           0  Sacramento      Kings               SAC  ...
# 1    rockets           0     Houston    Rockets               HOU  ...
# 2       heat           0       Miami       Heat               MIA  ...
# 3    raptors           0     Toronto    Raptors               TOR  ...
# 4  grizzlies           0     Memphis  Grizzlies               MEM  ...
#
# ...
